# %%
# CÓDIGO DA AUTOMAÇÃO DE LOGIN.

import pyautogui as py
import time
py.PAUSE = 0.5
py.press("win")
time.sleep(5)
py.write("chrome")
time.sleep(3)
py.press("enter") 
time.sleep(7)
py.write("https://pages.hashtagtreinamentos.com/aula1-intensivao-sistema")
py.press("enter")
time.sleep(5)
py.click(x=818, y=419)
py.write("fernando1234")
py.click(x=904, y=535)
py.write("1234")
py.click(x=938, y=625)
time.sleep(10)
py.click(x=1657, y=411)
py.press("enter")

# %%
# CÓDIGO DA AUTOMAÇÃO PARA O ENVIO DO EMAIL COM AS INFORMAÇÕES FILTRADAS E EDITADAS DO ARQUIVO BAIXADO.

import pandas as pd
import pyperclip

tabela = pd.read_csv(r"C:\Users\fndrd\Downloads\Compras.csv",sep= ";")
to_g = tabela ["ValorFinal"].sum()
quantidade = tabela ["Quantidade"].sum()
p_m = to_g / quantidade
print(to_g)
print(quantidade)
print(p_m )
py.hotkey("ctrl", "t")
time.sleep(5)
py.click(x=1667, y=128)
py.press("enter")
time.sleep(10)
py.click(x=111, y=204)
time.sleep(25)
py.write("santananando79@gmail.com")
py.press("tab")
pyperclip.copy("Relatório de Compras")
py.hotkey("ctrl", "v")
py.press("tab")
texto = f"""
Prezados, estou enviando o relatório de compras.
Total gasto: R${to_g:,.2f}
Quantidade: {quantidade:,}
Preço médio: R${p_m:,.2f}
Ass: Fernando Santana
"""
pyperclip.copy(texto)
py.hotkey("ctrl", "v")
py.hotkey("ctrl", "enter")
# Out:
#       CódigoCompra        Data               Fornecedor  \
# 0            65014  01/12/2023   Fabrica Hashtag Brasil
# 1            65014  01/12/2023   Fabrica Hashtag Brasil
# 2            65016  01/12/2023   Fabrica Doidona Brasil
# 3            65016  01/12/2023   Fabrica Doidona Brasil
# 4            65017  01/12/2023  Original Fábrica Brasil
# ...            ...         ...                      ...
# 4538         69996  26/12/2023        Revenda Argentina
# 4539         69996  26/12/2023        Revenda Argentina
# 4540         69996  26/12/2023        Revenda Argentina
# 4541         69997  26/12/2023   Fabrica Doidona Mexico
# 4542         69997  26/12/2023   Fabrica Doidona Mexico
#
#                             Produto  Quantidade  ValorUnitário  ValorFinal
# 0              Óleo Motor - Linha A           5         259.00     1295.00
# 1           Kit Embreagem - Linha A           1         380.00      380.00
# ...
